# %%
import numpy as np
import matplotlib.pyplot as plt

import utils as util
import public_tests as pt
import logistic_reg as lr

X,y= util.load_data("data/ex2data1.txt", ',')
w=np.ones(X.shape[1])
b=-8
alpha=0.001
num_iterations=100000

w_opt,b_opt,cost=lr.gradient_descent(X, y, w, b, lr.compute_cost, lr.compute_gradient, alpha, num_iterations)


util.plot_decision_boundary(w_opt,b_opt,X,y)

# %%
X,y= util.load_data("data/ex2data2.txt", ',')
map_feat = util.map_feature(X[0],X[1])

w=np.ones(map_feat.shape[1])
b=-8
alpha=0.001
num_iterations=100000

w_opt,b_opt,cost=lr.gradient_descent(map_feat, y, w, b, lr.compute_cost_reg, lr.compute_gradient_reg, alpha, num_iterations)


util.plot_decision_boundary(w_opt,b_opt,map_feat,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 9
#       6 alpha=0.001
#       7 num_iterations=100000
# ----> 9 w_opt,b_opt,cost=lr.gradient_descent(map_feat, y, w, b, lr.compute_cost_reg, lr.compute_gradient_reg, alpha, num_iterations)
#      12 util.plot_decision_boundary(w_opt,b_opt,map_feat,y)
#
# File ~\Documents\GitHub\Anotaciones-23-24\AAaaaaa\Practica 3\logistic_reg.py:173, in gradient_descent(X, y, w_in, b_in, cost_function, gradient_function, alpha, num_iters, lambda_)
#     170 J_history = np.zeros(num_iters)
#     172 for i in range(num_iters):
# --> 173     dj_db, dj_dw = gradient_function(X, y, w, b, lambda_)
#     175     w -= alpha * dj_dw
#     176     b -= alpha * dj_db
#
# File ~\Documents\GitHub\Anotaciones-23-24\AAaaaaa\Practica 3\logistic_reg.py:131, in compute_gradient_reg(X, y, w, b, lambda_)
# ...
