# %%
from utils import plot_data 
from utils import load_data
import numpy as np

# Data representation of the initial sets

X, decision = load_data();
#decision = np.array(decision)

plot_data(X, decision);

# %%
from logistic_reg import sigmoid
from public_tests import sigmoid_test

g = [-1,0,1,2]
result = sigmoid(g);
sigmoid_test(sigmoid);

print(result)
# Out:
# All tests passed!
# [0.26894142 0.5        0.73105858 0.88079708]

# %%
from logistic_reg import compute_cost
from public_tests import compute_cost_test

compute_cost_test(compute_cost);

w1 = 0
b1 = 0
val = compute_cost(X, decision, w1, b1);
print(val);

w2 = [0.2, 0.2]
b2 = -24
val = compute_cost(X, decision, w2, b2);
print(val);
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[3], line 4
#       1 from logistic_reg import compute_cost
#       2 from public_tests import compute_cost_test
# ----> 4 compute_cost_test(compute_cost);
#       6 w1 = 0
#       7 b1 = 0
#
# File ~\Documents\GitHub\Anotaciones-23-24\AAaaaaa\Practica 3\public_tests.py:26, in compute_cost_test(target)
#      24 b = 0
#      25 result = target(X, y, w, b)
# ---> 26 assert np.isclose(result, 2.15510667), f"Wrong output. Expected: {2.15510667} got: {result}"
#      28 X = np.random.randn(4, 3)
#      29 y = np.array([1, 1, 0, 0])
#
# AssertionError: Wrong output. Expected: 2.15510667 got: 5.5638142584019565

# %%
from logistic_reg import compute_gradient
from public_tests import compute_gradient_test

compute_gradient_test(compute_gradient);

w1 = 0
b1 = 0
val = compute_gradient(X[0], X[1], w1, b1);
print(val);

w2 = [0.2, -0.5]
b2 = -24
val = compute_gradient(X[0], X[1], w2, b2);
print(val);
# Out:
# All tests passed!
# (-36.59085414611354, -2208.6031432532923)
# (-37.09085414611354, -2236.765231363262)

# %%
from logistic_reg import compute_gradient
from public_tests import compute_gradient_test

compute_gradient_test(compute_gradient);
# Out:
# All tests passed!

# %%
from utils import load_data2

X2, decision2 = load_data2();

plot_data(X2, decision2);
