# %%
import matplotlib.pyplot as plt # para dibujar la gráfica
from utils import load_data


x, y = utils.load_data() #Two one-dimensional numpy arrays

plt.scatter(x, y, marker = '.')
plt.title('Data Pool')
plt.xlabel('Income (Thousands of Euros)')
plt.ylabel('Average Profit (Millions of Euros)')
plt.show()

# %%
from linear_reg import compute_cost
from linear_reg import compute_gradient
from linear_reg import gradient_descent

from public_tests import compute_gradient_descent_test
from public_tests import compute_gradient_test
from public_tests import compute_cost_test

#hiperparámetros
alpha = 0.01
iterations=1500
w_init = 0 
b_init=0

compute_cost_test(compute_cost)
cost = compute_cost(x,y,w_init, b_init)
print(f'Initial cost (Before iterations): {cost}')

compute_gradient_test(compute_gradient)
compute_gradient_descent_test(w,b)
w, b, J_history = gradient_descent(x, y, w_init, b_init,compute_cost, compute_gradient, alpha, iterations)
print(f'parameters: x={w} b= {b}')


plt.plot(range(1, iterations + 1), J_history, color='r')
plt.xlabel('iterations')
plt.ylabel('cost')
plt.title('Learning Curve')
plt.show()
# Out:
# Testing: compute_cost_test
# Cost case 1
# Case 1 passed!
# Cost case 2
# Case 2 passed!
# Cost case 3
# Case 3 passed!
# Cost case 4
# Case 4 passed!
# Cost case 5
# Case 5 passed!
# All tests passed!
# Initial cost (Before iterations): 32.16082638261031
# Testing: compute_gradient_test
# Using X with shape (4, 1)
# Case 1
# 0.0 0.0
# Case 1 passed!
# Case 2
# Case 2 passed!
# All tests passed!
# Testing: compute_gradient_descent_test
# Case 1
# Case 1 passed!
# Case 2
# Case 2 passed!
# All tests passed!
# parameters: x=1.1559864086837552 b= -3.553366921533516

# %%
plt.scatter(x, y, marker='.', label='Data')
plt.plot(x, w * x + b, color='r', label='Lineal regression')
plt.xlabel('Income (Thousands of Euros)')
plt.ylabel('Average Profit (Millions of Euros)')
plt.legend()
plt.show()
