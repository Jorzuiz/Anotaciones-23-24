# %% [markdown]
# # Moviditas de presupuesto para el destiny

# %%
import pandas as pd
import numpy as np
vault = pd.read_csv('vault.csv')

# %%
display(vault)
# Out:
#                   Name        Hash                     Id  Tag       Tier  \
# 0       Ballyhoo Mk.27   653875712  "6917529029864563947"  NaN       Rare
# 1       Traitor's Fate  2683682446  "6917529029939152577"  NaN  Legendary
# 2       MIDA Mini-Tool  3089417788  "6917529030672961475"  NaN  Legendary
# 3        Better Devils  1048266744  "6917529047227282966"  NaN  Legendary
# 4           Sorrow MG2  1195725819  "6917529048187880675"  NaN     Common
# ..                 ...         ...                    ...  ...        ...
# 458     Coriolis Force  3512349612  "6917530007987290212"  NaN  Legendary
# 459  The Guiding Sight  1161561386  "6917530008009881069"  NaN  Legendary
# 460         Parabellum  3926811686  "6917530008009881616"  NaN  Legendary
# 461        Adhortative  2993554824  "6917530010301698144"  NaN  Legendary
# 462   Scalar Potential  2563668388  "6917530010305364418"  NaN  Legendary
#
#                Type           Source     Category  Element  Power  ...  \
# ...

# %%
vault[vault["Crafted"] & vault["Crafted Level"]>=1]
# Out:
#                       Name        Hash                     Id       Tag  \
# 210            Red Herring  3175851496  "6917529671726560542"  favorite
# 213     Empirical Evidence  2607304614  "6917529691663522809"       NaN
# 221             The Enigma  2595497736  "6917529761893795008"  favorite
# 222  Explosive Personality  4096943616  "6917529762271519445"  favorite
# 230         The Other Half  3257091167  "6917529817879754475"  favorite
# 239          Brigand's Law  1298815317  "6917529836063338686"  favorite
# 245              Ammit AR2  2119346509  "6917529837705996910"  favorite
# 246        Planck's Stride   820890091  "6917529837706002172"       NaN
# 248          Hollow Denial  2323544076  "6917529839191959073"  favorite
# 256        CALUS Mini-Tool  2490988246  "6917529845821104379"  favorite
# 264              Tarnation  2721157927  "6917529852953251614"  favorite
# 278              Palmyra-B  3489657138  "6917529871672734281"  favorite
# ...

# %%
vault = vault.drop(columns=['Hash'])

display(vault)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 vault = vault.drop(columns=['Hash'])
#       3 display(vault)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
# ...
